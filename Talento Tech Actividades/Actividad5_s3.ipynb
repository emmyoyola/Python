# %% [markdown]
# # Actividad 5
#
# ## Contexto: Desafíos en la Educación en Colombia
#
# En Colombia, la educación enfrenta retos significativos, como la falta de acceso y la deserción escolar. A menudo, los estudiantes no logran alcanzar un rendimiento académico óptimo debido a factores como la asistencia irregular y la desigualdad en las oportunidades educativas.<br>
# Este conjunto de datos simulado representa a estudiantes colombianos, incluyendo información sobre su rendimiento,
# asistencia ycaracterísticas demográficas. A través de este análisis, se busca resaltar cómo estas variables pueden afectar el desempeño educativo.
#
# ## Descripción del Conjunto de Datos
#
# - student_id: Identificación única para cada estudiante
# (algunos registrospueden estar duplicados).
# - age: Edad del estudiante, variando entre 6 y 17 años.
# - score: Calificación promedio en exámenes, con algunas calificacionesfaltantes.
# - attendance: Porcentaje de asistencia a clases, también con valores faltantes.
# - gender: Género del estudiante, “Masculino” o “Femenino”.
# - grade: Grado escolar, ya sea “Primaria” o “Secundaria”.
# - region: Región de Colombia a la que pertenece el estudiante, incluyendo “Caribe”, “Pacífico”, “Andino” y “Amazonía”.

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv(r'C:\Users\EMMY\Desktop\Talento Tech\Analisis de datos\Clases\DB\Educacion.csv')
df1.head()
# Out:
#    student_id  age  score  attendance     gender       grade    region
# 0           1    6   75.9   93.050075  Masculino    Primaria    Andino
# 1           2   10   71.3   29.684641  Masculino  Secundaria  Amazonía
# 2           3    6    NaN   65.321825   Femenino    Primaria  Amazonía
# 3           4   14   72.7   90.107048  Masculino  Secundaria    Caribe
# 4           5   15   77.3         NaN   Femenino  Secundaria    Andino

# %%
df = df1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  110 non-null    int64
#  1   age         110 non-null    int64
#  2   score       99 non-null     float64
#  3   attendance  99 non-null     float64
#  4   gender      110 non-null    object
#  5   grade       110 non-null    object
#  6   region      110 non-null    object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 6.1+ KB

# %% [markdown]
# ### Preguntas sobre Manejo de Datos Faltantes
# #### 1. ¿Cuántos valores faltantes hay en todo el DataFrame?

# %%
df.isna().sum().sum()
# Out:
# np.int64(22)

# %% [markdown]
# R/ En la base de datos se encuentran 22 datos faltantes

# %% [markdown]
# #### 2. ¿Qué porcentaje de valores faltantes hay en la columna ‘score’?

# %%
tot = df.shape[0]
NScore = df['score'].isna().sum()
(NScore/tot)*100
# Out:
# np.float64(10.0)

# %% [markdown]
# R/ Score tiene un 10% de valores faltantes

# %% [markdown]
# #### 3. Rellena los valores faltantes de ‘score’ con la media.

# %%
df['score'].mean()
# Out:
# np.float64(73.05050505050505)

# %%
df
# Out:
#      student_id  age  score  attendance     gender       grade    region
# 0             1    6   75.9   93.050075  Masculino    Primaria    Andino
# 1             2   10   71.3   29.684641  Masculino  Secundaria  Amazonía
# 2             3    6    NaN   65.321825   Femenino    Primaria  Amazonía
# 3             4   14   72.7   90.107048  Masculino  Secundaria    Caribe
# 4             5   15   77.3         NaN   Femenino  Secundaria    Andino
# ..          ...  ...    ...         ...        ...         ...       ...
# 105         100   15   61.8   14.592869  Masculino    Primaria  Amazonía
# 106          54    7   65.5   39.002290  Masculino    Primaria    Caribe
# 107          34   16   85.9   80.641967  Masculino  Secundaria  Pacífico
# 108           1    6   75.9   93.050075  Masculino    Primaria    Andino
# 109          77   14   66.8   52.479060  Masculino    Primaria  Pacífico
#
# [110 rows x 7 columns]

# %%
df['score'] = df['score'].fillna(df['score'].mean())
df
# Out:
#      student_id  age      score  attendance     gender       grade    region
# 0             1    6  75.900000   93.050075  Masculino    Primaria    Andino
# 1             2   10  71.300000   29.684641  Masculino  Secundaria  Amazonía
# 2             3    6  73.050505   65.321825   Femenino    Primaria  Amazonía
# 3             4   14  72.700000   90.107048  Masculino  Secundaria    Caribe
# 4             5   15  77.300000         NaN   Femenino  Secundaria    Andino
# ..          ...  ...        ...         ...        ...         ...       ...
# 105         100   15  61.800000   14.592869  Masculino    Primaria  Amazonía
# 106          54    7  65.500000   39.002290  Masculino    Primaria    Caribe
# 107          34   16  85.900000   80.641967  Masculino  Secundaria  Pacífico
# 108           1    6  75.900000   93.050075  Masculino    Primaria    Andino
# 109          77   14  66.800000   52.479060  Masculino    Primaria  Pacífico
#
# [110 rows x 7 columns]

# %%
df = df.dropna(subset=['attendance'])
df
# Out:
#      student_id  age      score  attendance     gender       grade    region
# 0             1    6  75.900000   93.050075  Masculino    Primaria    Andino
# 1             2   10  71.300000   29.684641  Masculino  Secundaria  Amazonía
# 2             3    6  73.050505   65.321825   Femenino    Primaria  Amazonía
# 3             4   14  72.700000   90.107048  Masculino  Secundaria    Caribe
# 5             6    9  72.300000   43.033322   Femenino    Primaria    Andino
# ..          ...  ...        ...         ...        ...         ...       ...
# 105         100   15  61.800000   14.592869  Masculino    Primaria  Amazonía
# 106          54    7  65.500000   39.002290  Masculino    Primaria    Caribe
# 107          34   16  85.900000   80.641967  Masculino  Secundaria  Pacífico
# 108           1    6  75.900000   93.050075  Masculino    Primaria    Andino
# 109          77   14  66.800000   52.479060  Masculino    Primaria  Pacífico
#
# [99 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 109
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  99 non-null     int64
#  1   age         99 non-null     int64
#  2   score       99 non-null     float64
#  3   attendance  99 non-null     float64
#  4   gender      99 non-null     object
#  5   grade       99 non-null     object
#  6   region      99 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 6.2+ KB

# %% [markdown]
# #### 5. ¿Cuántos valores faltantes hay en cada columna?

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# R/ Ya no hay valores faltantes
# ### Preguntas sobre Registros Duplicados
# #### 6. ¿Cuántos registros duplicados hay en el DataFrame?

# %%
df.duplicated().sum()
# Out:
# np.int64(10)

# %% [markdown]
# #### 8. Muestra los registros duplicados.

# %%
df[df.duplicated()]
# Out:
#      student_id  age  score  attendance     gender       grade    region
# 100          61   10   83.6   96.647738   Femenino  Secundaria    Andino
# 101          12    9   62.9   35.840015   Femenino    Primaria    Caribe
# 102          35   11   68.5   91.005901   Femenino    Primaria  Pacífico
# 103          52   10   71.2   61.587103  Masculino  Secundaria    Andino
# 104          32   15   77.3   95.443424   Femenino    Primaria  Pacífico
# 105         100   15   61.8   14.592869  Masculino    Primaria  Amazonía
# 106          54    7   65.5   39.002290  Masculino    Primaria    Caribe
# 107          34   16   85.9   80.641967  Masculino  Secundaria  Pacífico
# 108           1    6   75.9   93.050075  Masculino    Primaria    Andino
# 109          77   14   66.8   52.479060  Masculino    Primaria  Pacífico

# %% [markdown]
# #### 7. Elimina los registros duplicados.

# %%
df = df.drop_duplicates()
df
# Out:
#     student_id  age      score  attendance     gender       grade    region
# 0            1    6  75.900000   93.050075  Masculino    Primaria    Andino
# 1            2   10  71.300000   29.684641  Masculino  Secundaria  Amazonía
# 2            3    6  73.050505   65.321825   Femenino    Primaria  Amazonía
# 3            4   14  72.700000   90.107048  Masculino  Secundaria    Caribe
# 5            6    9  72.300000   43.033322   Femenino    Primaria    Andino
# ..         ...  ...        ...         ...        ...         ...       ...
# 95          96    9  73.050505   12.489583   Femenino  Secundaria    Andino
# 96          97   14  65.000000   58.155422   Femenino  Secundaria  Pacífico
# 97          98    9  70.000000   24.014961   Femenino  Secundaria  Amazonía
# 98          99   12  73.050505   72.188789  Masculino  Secundaria    Andino
# 99         100   15  61.800000   14.592869  Masculino    Primaria  Amazonía
#
# [89 rows x 7 columns]

# %% [markdown]
# #### 9. ¿Cuántos estudiantes únicos hay en el DataFrame después de eliminar duplicados?

# %%
df['student_id'].nunique()
# Out:
# 89

# %% [markdown]
# ### Preguntas sobre Transformación de Datos
# #### 10. Transforma la columna ‘attendance’ a un rango de 0 a 1 (Normalizar la varible)

# %%
df['attendance'] = (df['attendance'] - df['attendance'].min()) / (df['attendance'].max() - df['attendance'].min())
df
# Out:
# C:\Users\EMMY\AppData\Local\Temp\ipykernel_45888\1605690876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['attendance'] = (df['attendance'] - df['attendance'].min()) / (df['attendance'].max() - df['attendance'].min())
#     student_id  age      score  attendance     gender       grade    region
# 0            1    6  75.900000    0.949097  Masculino    Primaria    Andino
# 1            2   10  71.300000    0.301123  Masculino  Secundaria  Amazonía
# 2            3    6  73.050505    0.665548   Femenino    Primaria  Amazonía
# 3            4   14  72.700000    0.919002  Masculino  Secundaria    Caribe
# 5            6    9  72.300000    0.437626   Femenino    Primaria    Andino
# ...

# %% [markdown]
# #### 11.	Crea una nueva columna que indique si el estudiante aprobó (score >= 60).

# %%
df['approved'] = df['score'].apply(lambda x: 'Sí' if x > 60 else 'No')
# Out:
# C:\Users\EMMY\AppData\Local\Temp\ipykernel_45888\1027624638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['approved'] = df['score'].apply(lambda x: 'Sí' if x > 60 else 'No')

# %%
df[df['approved'] == 'No']
# Out:
#     student_id  age  score  attendance     gender       grade    region  \
# 21          22    9   56.1    0.543461   Femenino  Secundaria    Caribe
# 40          41    7   58.8    0.484030  Masculino  Secundaria    Andino
# 49          50   12   59.5    0.655983   Femenino  Secundaria    Caribe
# 59          60   11   53.9    0.723897  Masculino  Secundaria  Pacífico
# 86          87    7   54.2    0.522406  Masculino  Secundaria    Andino
# 87          88   13   56.1    0.642548   Femenino  Secundaria    Andino
# 92          93   12   56.5    0.268523   Femenino  Secundaria  Amazonía
#
#    approved
# 21       No
# 40       No
# 49       No
# 59       No
# 86       No
# 87       No
# 92       No

# %% [markdown]
# #### 12.	Crea un DataFrame que contenga solo estudiantes de secundaria.

# %%
df[df['grade'] == 'Secundaria']
# Out:
#     student_id  age      score  attendance     gender       grade    region  \
# 1            2   10  71.300000    0.301123  Masculino  Secundaria  Amazonía
# 3            4   14  72.700000    0.919002  Masculino  Secundaria    Caribe
# 8            9    6  77.600000    0.283698   Femenino  Secundaria  Pacífico
# 12          13   14  73.050505    0.858604  Masculino  Secundaria    Caribe
# 16          17    7  91.000000    0.000000  Masculino  Secundaria  Amazonía
# 17          18    8  73.050505    0.161624  Masculino  Secundaria    Caribe
# 21          22    9  56.100000    0.543461   Femenino  Secundaria    Caribe
# 24          25    9  66.500000    0.296391  Masculino  Secundaria    Andino
# 27          28   13  66.100000    0.814212   Femenino  Secundaria  Amazonía
# 28          29    8  72.800000    0.365484  Masculino  Secundaria    Caribe
# 32          33   13  82.400000    0.379346  Masculino  Secundaria    Andino
# ...

# %% [markdown]
# #### 13.	Convierte la columna ‘grade’ a un tipo categórico.

# %%
df.dtypes
# Out:
# student_id      int64
# age             int64
# score         float64
# attendance    float64
# gender         object
# grade          object
# region         object
# approved       object
# dtype: object

# %%
# Convertir la columna 'grade' a categórico
df['grade'] = df['grade'].astype('category')

df['grade'].dtypes
# Out:
# C:\Users\EMMY\AppData\Local\Temp\ipykernel_45888\2368848044.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['grade'] = df['grade'].astype('category')
# CategoricalDtype(categories=['Primaria', 'Secundaria'], ordered=False, categories_dtype=object)

# %% [markdown]
# #### 14.	¿Cuál es la calificación promedio por grado?

# %%
promedio_grado = df.groupby('grade', observed=True)['score'].mean()
promedio_grado
# Out:
# grade
# Primaria      72.675623
# Secundaria    72.681864
# Name: score, dtype: float64

# %% [markdown]
# # Clase 'Categorical Data'
# ## Aplicación
#
# Retomando la problematica Desafíos en la Educación en
# Colombia aplica la función groupby para dar respuesta a los
# siguientes interrogantes.
#
# 1. ¿Cuál es la calificación promedio de los estudiantes por género?

# %%
df.groupby('gender')['score'].mean()
# Out:
# gender
# Femenino     73.234848
# Masculino    72.083768
# Name: score, dtype: float64

# %% [markdown]
# 2. ¿Cuál es el porcentaje de asistencia promedio por grado?

# %%
df.groupby('grade', observed=True)['attendance'].mean()
# Out:
# grade
# Primaria      0.500689
# Secundaria    0.542525
# Name: attendance, dtype: float64

# %% [markdown]
# 3. ¿Cuál es la calificación promedio por región?

# %%
df.groupby('region', observed=True)['score'].mean()
# Out:
# region
# Amazonía    72.421106
# Andino      73.382061
# Caribe      74.128620
# Pacífico    70.881313
# Name: score, dtype: float64

# %% [markdown]
# 4. ¿Cuál es la edad promedio de los estudiantes por género y por grado?

# %%
df.groupby(['gender', 'grade'], observed=True)['age'].mean()
# Out:
# gender     grade
# Femenino   Primaria      11.320000
#            Secundaria    11.095238
# Masculino  Primaria      10.950000
#            Secundaria     9.956522
# Name: age, dtype: float64

# %% [markdown]
# 5. ¿Cuál es la asistencia promedio por región y por grado?

# %%
df.groupby(['region', 'grade'], observed=True)['attendance'].mean()
# Out:
# region    grade
# Amazonía  Primaria      0.430313
#           Secundaria    0.370525
# Andino    Primaria      0.536725
#           Secundaria    0.616340
# Caribe    Primaria      0.406190
#           Secundaria    0.684219
# Pacífico  Primaria      0.567149
#           Secundaria    0.376594
# Name: attendance, dtype: float64

# %% [markdown]
# 6. ¿Cuántos estudiantes hay en cada región?

# %%
df.groupby('region', observed=True).size()
# Out:
# region
# Amazonía    19
# Andino      25
# Caribe      21
# Pacífico    24
# dtype: int64

# %% [markdown]
# 7. ¿Cuál es la calificación promedio por región y por género?

# %%
df.groupby(['region', 'gender'], observed=True)['score'].mean()
# Out:
# region    gender
# Amazonía  Femenino     71.235051
#           Masculino    73.738945
# Andino    Femenino     75.477001
#           Masculino    71.112542
# Caribe    Femenino     71.987500
#           Masculino    75.446232
# Pacífico  Femenino     73.290101
#           Masculino    66.866667
# Name: score, dtype: float64

# %% [markdown]
# 8. ¿Cuál es la edad promedio de los estudiantes por región?

# %%
df.groupby('region', observed=True)['age'].mean()
# Out:
# region
# Amazonía    10.631579
# Andino      11.120000
# Caribe      10.380952
# Pacífico    11.083333
# Name: age, dtype: float64

# %% [markdown]
# 9. ¿Cuál es la asistencia promedio de los estudiantes por género?

# %%
df.groupby('gender', observed=True)['attendance'].mean()
# Out:
# gender
# Femenino     0.539565
# Masculino    0.501909
# Name: attendance, dtype: float64

# %% [markdown]
# 10. ¿Cuántos estudiantes hay en cada combinación de grado yregión?

# %%
df.groupby(['grade', 'region'], observed=True).size()
# Out:
# grade       region
# Primaria    Amazonía    10
#             Andino      11
#             Caribe       8
#             Pacífico    16
# Secundaria  Amazonía     9
#             Andino      14
#             Caribe      13
#             Pacífico     8
# dtype: int64
